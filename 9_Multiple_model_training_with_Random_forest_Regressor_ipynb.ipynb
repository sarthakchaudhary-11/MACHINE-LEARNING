# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#predictthe total_bill? total_bill is target variables
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
#EDA>> subjective
#encoding, missing value treatiment, scaling>> automate
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
X = df.drop('total_bill', axis =1)
y = df['total_bill']

# %%
X
# Out:
#       tip     sex smoker   day    time  size
# 0    1.01  Female     No   Sun  Dinner     2
# 1    1.66    Male     No   Sun  Dinner     3
# 2    3.50    Male     No   Sun  Dinner     3
# 3    3.31    Male     No   Sun  Dinner     2
# 4    3.61  Female     No   Sun  Dinner     4
# ..    ...     ...    ...   ...     ...   ...
# 239  5.92    Male     No   Sat  Dinner     3
# 240  2.00  Female    Yes   Sat  Dinner     2
# 241  2.00    Male    Yes   Sat  Dinner     2
# 242  1.75    Male     No   Sat  Dinner     2
# 243  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
y
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
X_train.head()
# Out:
#       tip     sex smoker  day    time  size
# 0    1.01  Female     No  Sun  Dinner     2
# 154  2.00    Male     No  Sun  Dinner     4
# 167  4.50    Male     No  Sun  Dinner     4
# 110  3.00    Male     No  Sat  Dinner     2
# 225  2.50  Female    Yes  Fri   Lunch     2

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#Handling the missing value
#data encoding
#feature scaling

from sklearn.impute import SimpleImputer #for missing vlaue
from sklearn.preprocessing import OneHotEncoder #for encoding
from sklearn.preprocessing import StandardScaler #for scaling

from sklearn.pipeline import Pipeline #A sequence of data transformers
from sklearn.compose import ColumnTransformer #Groups all the pipeline steps for each of the clumns

# %%
cat_cols = ["sex", "smoker", "day", "time"]
num_cols = ["tip", "size"]

# %%
#feature engineering automation using pipeline and columntransformer

num_pipeline = Pipeline(steps = [('imputation', SimpleImputer(strategy = "median")),
                                ('scaling', StandardScaler())])
cat_pipeline = Pipeline(steps = [('imputation', SimpleImputer(strategy = "most_frequent")),
                                ('encoding', OneHotEncoder())])

# %%
preprocessor = ColumnTransformer([("num_pipeline", num_pipeline, num_cols),
                  ("cat_pipeline", cat_pipeline, cat_cols)])

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
X_train
# Out:
# array([[-1.47443803, -0.57766863,  1.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.71612531,  1.47042924,  0.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.19880579,  1.47042924,  0.        , ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.43283335, -0.57766863,  1.        , ...,  1.        ,
#          0.        ,  1.        ],
#        [-1.29060464, -0.57766863,  0.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.1034652 ,  0.44638031,  1.        , ...,  0.        ,
#          1.        ,  0.        ]])

# %%
# X_test

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
models = {"support vector Regressor": SVR(),
         "DT Regressor": DecisionTreeRegressor(),
          "Multiple Linear regression": LinearRegression(),
         "Random_forest_Regressor": RandomForestRegressor()}

# %%
from sklearn.metrics import r2_score
def model_train_eval(X_train, y_train, X_test, y_test, models):
    evaluation = {}
    for i in range(len(models)):
        model = list(models.values())[i]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        model_score = r2_score(y_test, y_pred)
        evaluation[list(models.keys())[i]] = model_score
    return evaluation

# %%
model_train_eval(X_train, y_train, X_test, y_test, models)
# Out:
# {'support vector Regressor': 0.4069433055293954,
#  'DT Regressor': 0.14082929724210302,
#  'Multiple Linear regression': 0.6719006761625259,
#  'Random_forest_Regressor': 0.6409838610911662}

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(oob_score=True)

# %%
rfr
# Out:
# RandomForestRegressor(oob_score=True)

# %%
# X_train, X_test

# %%
from sklearn.model_selection import RandomizedSearchCV
params={'max_depth':[1,50, 100, 150,200],
        'n_estimators':[50, 100,200]}

# %%
params
# Out:
# {'max_depth': [1, 50, 100, 150, 200], 'n_estimators': [50, 100, 200]}

# %%
reg = RandomizedSearchCV(rfr, param_distributions=params, cv = 5, verbose =3, scoring = 'r2')

# %%
reg
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(oob_score=True),
#                    param_distributions={'max_depth': [1, 50, 100, 150, 200],
#                                         'n_estimators': [50, 100, 200]},
#                    scoring='r2', verbose=3)

# %%
reg.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .....max_depth=1, n_estimators=200;, score=0.227 total time=   0.4s
# [CV 2/5] END .....max_depth=1, n_estimators=200;, score=0.253 total time=   0.4s
# [CV 3/5] END .....max_depth=1, n_estimators=200;, score=0.369 total time=   0.3s
# [CV 4/5] END .....max_depth=1, n_estimators=200;, score=0.477 total time=   0.4s
# [CV 5/5] END .....max_depth=1, n_estimators=200;, score=0.400 total time=   0.3s
# [CV 1/5] END ....max_depth=200, n_estimators=50;, score=0.283 total time=   0.0s
# [CV 2/5] END ....max_depth=200, n_estimators=50;, score=0.506 total time=   0.0s
# [CV 3/5] END ....max_depth=200, n_estimators=50;, score=0.194 total time=   0.0s
# [CV 4/5] END ....max_depth=200, n_estimators=50;, score=0.606 total time=   0.0s
# [CV 5/5] END ....max_depth=200, n_estimators=50;, score=0.337 total time=   0.0s
# [CV 1/5] END ....max_depth=50, n_estimators=100;, score=0.323 total time=   0.2s
# [CV 2/5] END ....max_depth=50, n_estimators=100;, score=0.478 total time=   0.2s
# [CV 3/5] END ....max_depth=50, n_estimators=100;, score=0.170 total time=   0.2s
# [CV 4/5] END ....max_depth=50, n_estimators=100;, score=0.612 total time=   0.2s
# [CV 5/5] END ....max_depth=50, n_estimators=100;, score=0.350 total time=   0.2s
# [CV 1/5] END ...max_depth=150, n_estimators=100;, score=0.323 total time=   0.2s
# [CV 2/5] END ...max_depth=150, n_estimators=100;, score=0.504 total time=   0.2s
# [CV 3/5] END ...max_depth=150, n_estimators=100;, score=0.173 total time=   0.2s
# [CV 4/5] END ...max_depth=150, n_estimators=100;, score=0.584 total time=   0.2s
# [CV 5/5] END ...max_depth=150, n_estimators=100;, score=0.341 total time=   0.2s
# [CV 1/5] END ...max_depth=150, n_estimators=200;, score=0.294 total time=   0.4s
# [CV 2/5] END ...max_depth=150, n_estimators=200;, score=0.477 total time=   0.4s
# [CV 3/5] END ...max_depth=150, n_estimators=200;, score=0.240 total time=   0.4s
# [CV 4/5] END ...max_depth=150, n_estimators=200;, score=0.565 total time=   0.4s
# [CV 5/5] END ...max_depth=150, n_estimators=200;, score=0.373 total time=   0.5s
# [CV 1/5] END .....max_depth=1, n_estimators=100;, score=0.244 total time=   0.1s
# [CV 2/5] END .....max_depth=1, n_estimators=100;, score=0.264 total time=   0.1s
# [CV 3/5] END .....max_depth=1, n_estimators=100;, score=0.426 total time=   0.1s
# [CV 4/5] END .....max_depth=1, n_estimators=100;, score=0.468 total time=   0.1s
# [CV 5/5] END .....max_depth=1, n_estimators=100;, score=0.388 total time=   0.1s
# [CV 1/5] END ....max_depth=150, n_estimators=50;, score=0.296 total time=   0.0s
# [CV 2/5] END ....max_depth=150, n_estimators=50;, score=0.505 total time=   0.1s
# [CV 3/5] END ....max_depth=150, n_estimators=50;, score=0.211 total time=   0.0s
# [CV 4/5] END ....max_depth=150, n_estimators=50;, score=0.601 total time=   0.0s
# [CV 5/5] END ....max_depth=150, n_estimators=50;, score=0.330 total time=   0.0s
# [CV 1/5] END ....max_depth=50, n_estimators=200;, score=0.301 total time=   0.4s
# [CV 2/5] END ....max_depth=50, n_estimators=200;, score=0.497 total time=   0.4s
# [CV 3/5] END ....max_depth=50, n_estimators=200;, score=0.200 total time=   0.5s
# [CV 4/5] END ....max_depth=50, n_estimators=200;, score=0.598 total time=   0.5s
# [CV 5/5] END ....max_depth=50, n_estimators=200;, score=0.342 total time=   0.4s
# [CV 1/5] END ....max_depth=100, n_estimators=50;, score=0.364 total time=   0.0s
# [CV 2/5] END ....max_depth=100, n_estimators=50;, score=0.502 total time=   0.0s
# [CV 3/5] END ....max_depth=100, n_estimators=50;, score=0.272 total time=   0.0s
# [CV 4/5] END ....max_depth=100, n_estimators=50;, score=0.624 total time=   0.1s
# [CV 5/5] END ....max_depth=100, n_estimators=50;, score=0.352 total time=   0.0s
# [CV 1/5] END ...max_depth=100, n_estimators=200;, score=0.306 total time=   0.4s
# [CV 2/5] END ...max_depth=100, n_estimators=200;, score=0.475 total time=   0.4s
# [CV 3/5] END ...max_depth=100, n_estimators=200;, score=0.179 total time=   0.4s
# [CV 4/5] END ...max_depth=100, n_estimators=200;, score=0.599 total time=   0.5s
# [CV 5/5] END ...max_depth=100, n_estimators=200;, score=0.359 total time=   0.4s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(oob_score=True),
#                    param_distributions={'max_depth': [1, 50, 100, 150, 200],
#                                         'n_estimators': [50, 100, 200]},
#                    scoring='r2', verbose=3)

# %%
reg.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 100}

# %%
reg.best_score_
# Out:
# 0.4228061816288168
